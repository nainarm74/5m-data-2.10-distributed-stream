# %% [markdown]
# # Hands-on with Kafka
#
# ![kafka](https://images.contentful.com/gt6dp23g0g38/53UO4964r0e7kRVm0mcUUZ/f6f6d7b1b90e8e88a5be0d1845bdf950/what_is_kafka_and_how_does_it_work.png)

# %% [markdown]
# ## Installing Kafka Python Client
#
# First, we'll need to install Kafka Python client `kafka-python` to consume messages from a Kafka cluster.

# %%
import json
from kafka import KafkaConsumer, TopicPartition

# %% [markdown]
# First, we'll instantiate the consumer.
#
# Our data was serialized in JSON during publishing, hence we'll need to deserialize as JSON when consuming. In actual production, it is recommended to use the binary format that we've learnt, such as Avro.

# %%
consumer = KafkaConsumer(
  bootstrap_servers=['localhost:9092'],
  auto_offset_reset='earliest',
  value_deserializer = lambda v: json.loads(v.decode('ascii')),
  key_deserializer = lambda v: json.loads(v.decode('ascii')),
)

# %% [markdown]
# We set the offset for the consumer to be `earliest` to get the earliest order (message).
#
# List the available topics:

# %%
consumer.topics()
# Out:
# {'pizza-orders'}

# %% [markdown]
# Let's assume we are the owners of a pizza delivery chain, and we'd like to push the orders to Apache Kafka as they come in.
#
# We have a topic consisting of pizza orders, which contains the Order ID, Order Details (pizzas and toppings), client's Name, Address, Phone Number, the Shop Name, Total Cost and Timestamp.
#
# There is only one partition for the topic. First, let's subscribe to the topic:

# %%
topic_name = "pizza-orders"

# %%
consumer.subscribe(topics=[topic_name])
consumer.subscription()
# Out:
# {'pizza-orders'}

# %% [markdown]
# We can then start reading the events, let's read and (pretty) print the first 5:

# %%
from pprint import pprint

# %%
for ix, message in enumerate(consumer, start=1):
    print("%d:%d: k=%s" % (message.partition,
                           message.offset,
                           message.key))
    pprint("-------------------")
    pprint(message.value)
    print()
    if ix == 5:
        break
# Out:
# 0:0: k={'shop': 'Luigis Pizza'}
# '-------------------'
# {'address': '21087 Calvin Plains\nJonesland, NY 76392',
#  'cost': 6.95,
#  'id': 0,
#  'name': 'Jessica Smith',
#  'phoneNumber': '001-701-915-3000',
#  'pizzas': [{'additionalToppings': ['🥚 egg'], 'pizzaName': 'Marinara'},
#             {'additionalToppings': [], 'pizzaName': 'Salami'}],
#  'shop': 'Luigis Pizza',
#  'timestamp': 1781062635138}
#
# 0:1: k={'shop': 'Marios Pizza'}
# '-------------------'
# {'address': '19721 Drew Key\nNew Donaldport, NH 05690',
#  'cost': 36.27,
#  'id': 1,
#  'name': 'Roger Brown',
#  'phoneNumber': '475-943-3780x8105',
#  'pizzas': [{'additionalToppings': ['🍓 strawberry'], 'pizzaName': 'Salami'},
#             {'additionalToppings': ['🍍 pineapple'], 'pizzaName': 'Margherita'},
#             {'additionalToppings': ['🍌 banana', '🍓 strawberry', '🥚 egg'],
#              'pizzaName': 'Mari & Monti'},
#             {'additionalToppings': [], 'pizzaName': 'Margherita'},
#             {'additionalToppings': [], 'pizzaName': 'Marinara'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1781062636152}
#
# 0:2: k={'shop': 'Marios Pizza'}
# '-------------------'
# {'address': '278 Phillips Crossing Apt. 661\nPort Maryfurt, GU 86535',
#  'cost': 9.88,
#  'id': 2,
#  'name': 'Matthew Williams',
#  'phoneNumber': '924-927-0965x759',
#  'pizzas': [{'additionalToppings': [], 'pizzaName': 'Salami'}],
#  'shop': 'Marios Pizza',
#  'timestamp': 1781062638153}
#
# 0:3: k={'shop': 'Luigis Pizza'}
# '-------------------'
# {'address': '547 Brenda Walks\nLake Ronaldborough, CT 52490',
#  'cost': 30.94,
#  'id': 3,
#  'name': 'Corey Rodriguez',
#  'phoneNumber': '001-629-242-5711x630',
#  'pizzas': [{'additionalToppings': ['🍓 strawberry', '🌶️ hot pepper', '🥚 egg'],
#              'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🧅 onion'], 'pizzaName': 'Marinara'}],
#  'shop': 'Luigis Pizza',
#  'timestamp': 1781062639155}
#
# 0:4: k={'shop': 'Ill Make You a Pizza You Cant Refuse'}
# '-------------------'
# {'address': '752 Brandon Expressway Apt. 815\nNorth Elizabeth, AR 84161',
#  'cost': 48.32,
#  'id': 4,
#  'name': 'Stephen Stevens',
#  'phoneNumber': '253.786.2934',
#  'pizzas': [{'additionalToppings': ['🫒 olives'], 'pizzaName': 'Peperoni'},
#             {'additionalToppings': ['🥓 bacon'], 'pizzaName': 'Salami'}],
#  'shop': 'Ill Make You a Pizza You Cant Refuse',
#  'timestamp': 1781062641156}

# %% [markdown]
# Now, continue printing the next 5 events, notice the offset number and order id:

# %%
# consumer.seek_to_beginning()

# %%
for topic in consumer.topics():
    print(topic)
# Out:
# pizza-orders

# %%
for ix, message in enumerate(consumer, start=1):
    print("%d:%d: k=%s" % (message.partition,
                           message.offset,
                           message.key))
    pprint(message.value)
    print()
    if ix == 5:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 for ix, message in enumerate(consumer, start=1):
#       2     print("%d:%d: k=%s" % (message.partition,
#       3                            message.offset,
#       4                            message.key))
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~/miniconda3/envs/kafka/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
# go to beginning 
consumer.seek_to_beginning()

# %%
# close consumer 
consumer.close()

# %% [markdown]
# This is the full code to publish an example order:
#
# ```python
# from kafka import KafkaProducer
#
# producer = KafkaProducer(
#   bootstrap_servers=['brave-fish-11463-us1-kafka.upstash.io:9092'],
#   sasl_mechanism='SCRAM-SHA-256',
#   security_protocol='SASL_SSL',
#   sasl_plain_username='YnJhdmUtZmlzaC0xMTQ2MyQSvwXBuLOQsV1W7YffuC8cDaZcA3fKQwakMhnQGgg',
#   sasl_plain_password='MDUxNjc4YzEtYzYxNy00NTE1LWEwNWYtMDBhODRlZmE0OGJm',
#   value_serializer=lambda v: json.dumps(v).encode('ascii'),
#   key_serializer=lambda v: json.dumps(v).encode('ascii')
# )
#
# message = {'address': '8697 Anthony Valley\nPort Kellymouth, FL 64221',
#  'id': 10,
#  'name': 'Patricia Castaneda',
#  'phoneNumber': '328-798-9970x51560',
#  'pizzas': [{'additionalToppings': ['🍅 tomato'], 'pizzaName': 'Mari & Monti'}],
#  'shop': 'Mammamia Pizza',
#  'timestamp': 1696609343719}
#
# key = {'shop': 'Mammamia Pizza'}
#
# producer.send(topic_name, key=key, value=message)
# ```
